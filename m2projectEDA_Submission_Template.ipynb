# %% [markdown]
# <a href="https://colab.research.google.com/github/Haseena98/Paisabazaar-Banking-Fraud-Analysis/blob/main/m2projectEDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -Paisabazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Paisabazaar is a financial services company that assists customers in finding and applying for various banking and credit products. An integral part of their service is assessing the creditworthiness of individuals, which is crucial for both loan approval and risk management. The credit score of a person is a significant metric used by financial institutions to determine the likelihood that an individual will repay their loans or credit balances. Accurate classification of credit scores can help Paisabazaar enhance their credit assessment processes, reduce the risk of loan defaults, and offer personalized financial advice to their customers.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Paisabazaar fraud analysis

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To improve credit risk management and customer targeting by analyzing financial behavior patterns (e.g., income, debt, loan count, and payment behavior), enabling data-driven decisions for reducing loan defaults, enhancing credit score accuracy, and offering personalized financial products.

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
sheet_id = "1_PYaSkRKzBHvxZApNNGgG5aZfzdlVixVp-62rWwny98"   # sheet id
gid = "628330237"                                          # specific sheet tab

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"

df = pd.read_csv(url)

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name  Age        SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh   23  821000265  Scientist
# 1  5635         3392      2  Aaron Maashoh   23  821000265  Scientist
# 2  5636         3392      3  Aaron Maashoh   23  821000265  Scientist
# 3  5637         3392      4  Aaron Maashoh   23  821000265  Scientist
# 4  5638         3392      5  Aaron Maashoh   23  821000265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                  3  ...        Good
# 1       19114.12            1824.843333                  3  ...        Good
# 2       19114.12            1824.843333                  3  ...        Good
# 3       19114.12            1824.843333                  3  ...        Good
# 4       19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  int64
#  5   SSN                       100000 non-null  int64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(),cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  This data set consist of 100000 raws and 28 colums.
#  There is no null values and duplicated values in this data set.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %% [markdown]
# VARIABLE DISCRIPTION

# %% [markdown]
# Answer Here![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1988543898.py in <cell line: 0>()
#       1 # Check Unique Values for each variable.
# ----> 2 df.unique()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I droped duplicated values.I check whether there is any null values present in the data set, i found no null values.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1
sns.histplot(data=df,x='Annual_Income',bins=50)
plt.title("Annual Income Count")
# Out:
# Text(0.5, 1.0, 'Annual Income Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick histplot to analyze annual income because income is a univariate variable. The histplot groups the income values into ranges (bins) and shows how the data is distributed. It helps us to identify which income ranges are most common, whether the income distribution is skewed etc.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The annual income distribution is right-skewed, with most individuals earning between ₹10,000 and ₹40,000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes.This gained insights helped to create a positive business impact that company can target the people having this range of annual income.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2
sns.barplot(data=df,x='Occupation',y='Annual_Income')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because Barplot is used for bivariate analysis of categorical v/s continuous variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Annual income across professions shows very little variation, with most salaries clustered between ₹48,000 and ₹52,000. Architects, doctors, and managers earn slightly higher incomes, while teachers, mechanics, and media managers are on the lower side.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Since high-income customers are very few, the company must design risk-based loan products and use additional variables beyond income for assessment. Professions with slightly higher incomes—such as architects, doctors, and managers—represent lower-risk customer groups suitable for higher-value loans

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sns.barplot(data=df,x='Occupation',y='Num_of_Delayed_Payment')
plt.xticks(rotation=65)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Beacuse barplot is used for bivariate analysis of cataegorical and numerical column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is only a slight difference of delayed payments across all occupation,
#  indicating that profession alone does not significantly influence repayment behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights positively impact business decisions by showing that occupation does not significantly influence delayed payments. No insights indicate negative growth, as delayed payments remain consistent across all professions, implying stable repayment behavior.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
sns.boxplot(x='Credit_Score', y='Annual_Income', data=df)
plt.title('Annual Income by Credit Score Category')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The boxplot is ideal for visualizing the distribution of a numerical variable across different categories of a categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers with good credit scores tend to have higher median annual incomes, while poor credit score groups are concentrated in lower income ranges.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights help the business make better loan decisions and reduce risk. There are no insights that cause negative growth; instead, they help prevent losses.
#
# ---

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
sns.countplot(x='Credit_Score', data=df)
plt.title('Distribution of Credit Score Categories')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is the best choice to visualize the frequency (count) of observations in each credit score category — such as Good, Standard, and Poor.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers are in the “Standard” category
#
# This is the largest group.These customers have average credit behavior.
# The second largest group is “Poor”,A significant number of customers have low credit scores.This group is riskier for loan approval.
# The smallest group is “Good”.Fewer customers have very good credit scores.
# These are low-risk and trustworthy borrowers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, they will help the business
# Even though many customers are in the “Poor” category, this insight helps the company for Apply stricter rules,avoid risky loans and reduce future losses.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
sns.scatterplot(x='Outstanding_Debt', y='Monthly_Balance', hue='Credit_Score', data=df)
plt.title('Outstanding Debt vs Monthly Balance')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for analyzing the relationship between two continuous numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As outstanding debt increases, the monthly balance generally decreases.This means people with more debt usually keep less money monthly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes.The gained insights help creating a positive business impact,Customers with higher outstanding debt usually have lower monthly balances and poorer credit scores. This insight helps businesses reduce risk and make safer lending decisions

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
sns.lineplot(x='Age', y='Total_EMI_per_month', data=df)
plt.title('EMI per Month vs Age')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is suitable for observing trends over a continuous variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# People in the early 20s have higher EMI amounts.Between 25 to 45 years, EMI values are more stable.After 45–50 years, EMI amounts reduce.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# this insights helps to undestand that Younger customers pay higher EMIs, middle-aged customers show stable payments, and older customers have lower EMIs.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
sns.barplot(x='Occupation', y='Num_of_Loan', data=df)
plt.xticks(rotation=60)
plt.title('Average Number of Loans by Occupation')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is ideal when comparing the average value of a numerical column across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Doctors, entrepreneurs, and mechanics have slightly more loans.
# This may be due to Business or equipment needs and Higher investment requirements

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# People from different occupations have almost the same number of loans. Occupation alone should not be used to judge loan risk. This insight supports fair lending and better business decisions.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization
sns.countplot(x='Payment_Behaviour', hue='Credit_Score', data=df)
plt.xticks(rotation=85)
plt.title('Payment Behavior by Credit Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot with hue='Credit_Score' is ideal to visualize the frequency of payment behaviors and how they differ across credit score categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows the highest count of payment behaviour is Low Spent Medium Value Payments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customers with good credit scores pay on time, while poor credit score customers delay payments more often. This insight helps businesses reduce risk and make better lending decisions.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
selected_cols = ['Age','Annual_Income','Monthly_Inhand_Salary','Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Loan','Delay_from_due_date','Num_of_Delayed_Payment','Outstanding_Debt','Credit_Utilization_Ratio','Credit_History_Age',
'Total_EMI_per_month','Amount_invested_monthly','Monthly_Balance']
important_data = df[selected_cols]

# Calculate correlation matrix
corr_matrix = important_data.corr()

# Plot heatmap
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Key Financial Features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap of the correlation matrix is chosen to visually explore the relationships between numerical variables in the dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Monthly_Inhand_Salary may show a strong positive correlation with Annual_Income.
#
# 2.Monthly_Inhand_Salary may show a strong positive correlation with Annual_Invested_monthly

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
selected_cols = df[['Annual_Income','Num_of_Loan','Outstanding_Debt','Monthly_Balance','Credit_Score']]
sns.pairplot(data=selected_cols, hue='Credit_Score')
plt.suptitle("Pair Plot of Key Financial Metrics by Credit Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is chosen because it allows us to visually explore the relationships between multiple numerical variables in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart compares four financial variables together,
# Annual Income,number of Loans,outstanding Debt and Monthly Balance.
# Customers with good credit scores mostly have higher incomes.Customers with poor credit scores are more concentrated in lower income ranges.
# All credit score groups have a similar number of loans.This means number of loans alone does not decide credit score.
# Customers with poor credit scores tend to have higher outstanding debt.
# Good credit customers usually keep lower debt levels.
# Good credit score customers maintain higher monthly balances.Poor credit score customers have lower balances.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customers with good credit scores usually have higher income, lower debt, and higher monthly balance. Poor credit score customers show the opposite pattern. These insights help businesses reduce risk and make better lending decisions.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Optimize lending decisions, reduce default risk, and improve customer segmentation for better credit services.
#
# Use key features like payment behavior, credit utilization, and outstanding debt to create clear customer profiles.
#
# Target Good credit score customers with pre-approved offers, low-interest loans, and premium products.
#
# Design improvement programs (credit coaching, reminders, or limit adjustments) for Standard/Poor credit score customers.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project demonstrates that credit risk cannot be determined using a single factor. Customers with good credit scores tend to have higher income, lower debt, and better payment behavior, while poor credit score customers show higher risk due to higher debt and lower balances. Occupation and number of loans have minimal influence on risk. The insights help financial institutions make smarter loan decisions and prevent financial losses.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
